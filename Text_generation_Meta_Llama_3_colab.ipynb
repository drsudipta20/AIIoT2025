# %%
# !pip install -q transformers accelerate torch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 51.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 47.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.2 MB/s eta 0:00:00

# %%
from huggingface_hub import login
login()  # Paste your HF token here when prompted
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_id = "meta-llama/Meta-Llama-3-8B-Instruct"  # Or use mistralai/Mistral-7B-Instruct or google/gemma-7b-it

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_id, use_auth_token=True)
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto", torch_dtype="auto")

# Setup text generation pipeline
generator = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# Device set to use cuda:0

# %%
prompt = "Describe about BMW"
outputs = generator(prompt, max_new_tokens=500, do_sample=True, temperature=0.7)

print(outputs[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Describe about BMW 3 Series
# The BMW 3 Series is a compact luxury car produced by the German automaker BMW since 1975. It is the successor to the BMW 2002 and has been in production for over 40 years. The 3 Series is known for its sporty handling, powerful engines, and luxurious interior.
# The first generation of the 3 Series, the E21, was introduced in 1975 and was available with a range of inline-four and inline-six engines. The E21 was replaced by the E30 in 1982, which introduced a new design language and a range of new engines, including a turbocharged inline-four.
# The E36 generation, introduced in 1990, was the first 3 Series to be available with a V6 engine and a range of new safety features, including anti-lock brakes and airbags. The E46 generation, introduced in 1998, was the first 3 Series to be available with a diesel engine and a range of new technologies, including a electronic stability control system.
# The F30 generation, introduced in 2011, was the first 3 Series to be available with a range of new engines, including a turbocharged inline-four and a V6. It also introduced a new design language and a range of new safety features, including a rearview camera and a lane departure warning system.
# The current generation of the 3 Series, the G20, was introduced in 2019 and is available with a range of new engines, including a hybrid powertrain and a range of new safety features, including a 360-degree camera system and a parking assistant.
# The BMW 3 Series is known for its sporty handling and powerful engines, and is available in a range of body styles, including a sedan, wagon, and coupe. It is also available with a range of trim levels, including the base model, the 320i, and the high-performance M3.
# Here are some of the key features of the BMW 3 Series:
# * Powerful engines: The 3 Series is available with a range of powerful engines, including a turbocharged inline-four and a V6.
# * Sporty handling: The 3 Series is known for its sporty handling, thanks to its rear-wheel drive layout and a range of suspension options.
# * Luxurious interior: The 3 Series has a luxurious interior, with a range of premium materials and advanced technology features.
# * Advanced safety features: The 3
